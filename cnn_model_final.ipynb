# %% [markdown]
# # 1. Library importation

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install pydub
# !pip install noisereduce
# !pip install json-tricks

# %%
# %%capture
import numpy as np
import os
from json_tricks import dump, load

from pydub import AudioSegment, effects
import librosa
import noisereduce as nr

import tensorflow as tf
import keras
import sklearn

# %% [markdown]
# #2. Audio file preprocessing

# %%
import os
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

# %% [markdown]
# ## 2.1 CNN preprocessing(no need to run now)

# %%
# create spectrogram image from audio file
def create_spectrogram(audio_file, image_file):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

    y, sr = librosa.load(audio_file)
    ms = librosa.feature.melspectrogram(y, sr=sr)
    log_ms = librosa.power_to_db(ms, ref=np.max)
    librosa.display.specshow(log_ms, sr=sr)

    fig.savefig(image_file)
    plt.close(fig)
    
#  using create_spectrogram function to convert audio file to image
def create_pngs_from_wavs(input_path, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    dir = os.listdir(input_path)

    for i, file in enumerate(dir):
        input_file = os.path.join(input_path, file)
        output_file = os.path.join(output_path, file.replace('.wav', '.png'))
        create_spectrogram(input_file, output_file)

# %% [markdown]
# ## 2.2 Emotion labeling

# %%
def find_emotion_T(name): 
        if('neutral' in name): return 0
        elif('happy' in name): return 1
        elif('sad' in name): return 2
        elif('angry' in name): return 3
        elif('fear' in name): return 4
        elif('disgust' in name): return 5
        elif('ps' in name): return 6
        else: return -1

# %% [markdown]
# ##2.3 Load the spectrgram image and label the image

# %%
import numpy as np
import librosa.display, os
import matplotlib.pyplot as plt
import cv2

images = []
emotions = []
folder_path = '/content/drive/MyDrive/deep_learning/Speech_Emotion_Recognition/SPEC/' 

for subdir, dirs, files in os.walk(folder_path):
  i = 0
  for file in files: 
    # load all images will cause the ram overload and crash.
    i += 1
    if(i> 200): break

    path = os.path.join(subdir,file)
    img = cv2.imread(path)
    images.append(img)

    name = find_emotion_T(file)
    emotions.append(name)

# %% [markdown]
# #3. Data setup

# %%
f_images = np.asarray(images).astype('float32')
X = np.transpose(f_images, (0, 3, 1, 2))
print(f_images.shape)
# Out:
# (1400, 288, 432, 3)

# %%
# expand y to 2 dimension
Y = np.asarray(emotions).astype('int8')
Y = np.expand_dims(Y, axis=1)
print(Y.shape)
# Out:
# (1400, 1)

# %%
# Shuffle the data
from sklearn.utils import shuffle
for i in range(10):
    X, Y = shuffle(X, Y, random_state=i)

# %% [markdown]
# ## 3.1  Split train, val, test data and convert y to one hot vector

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
x_train, x_tosplit, y_train, y_tosplit = train_test_split(X, Y, test_size = 0.2, random_state = 1)
x_val, x_test, y_val, y_test = train_test_split(x_tosplit, y_tosplit, test_size = 0.4, random_state = 1)

y_train_class = tf.keras.utils.to_categorical(y_train, 7, dtype = 'int8')
y_val_class = tf.keras.utils.to_categorical(y_val, 7, dtype = 'int8')

# %%
# x_train, x_val, and x_test shape check.
print(np.shape(x_train))
print(np.shape(x_val))
print(np.shape(x_test))
# Out:
# (1120, 3, 288, 432)
# (168, 3, 288, 432)
# (112, 3, 288, 432)

# %% [markdown]
# ##3.2 Save the test data

# %%
# Save X,Y arrays as lists to json files.
x_test_data = x_test.tolist() 
x_test_path = 'drive/MyDrive/deep_learning/Speech_Emotion_Recognition/data_set/cnn_x_test.json' # FILE SAVE PATH
dump(obj = x_test_data, fp = x_test_path)

y_test_data = y_test.tolist() 
y_test_path = 'drive/MyDrive/deep_learning/Speech_Emotion_Recognition/data_set/cnn_y_test.json' # FILE SAVE PATH
dump(obj = y_test_data, fp = y_test_path)
# Out:
# '[[4], [0], [1], [6], [1], [2], [4], [0], [1], [1], [0], [1], [6], [6], [1], [1], [4], [6], [1], [5], [2], [2], [4], [6], [0], [4], [0], [4], [3], [3], [1], [5], [2], [2], [6], [6], [0], [6], [4], [4], [1], [0], [4], [1], [6], [5], [4], [6], [4], [2], [5], [6], [5], [6], [4], [3], [2], [2], [5], [3], [6], [5], [6], [4], [0], [0], [0], [2], [6], [0], [4], [4], [3], [1], [0], [4], [3], [1], [1], [0], [1], [4], [4], [2], [6], [4], [3], [1], [5], [0], [4], [3], [6], [3], [0], [6], [6], [4], [3], [1], [2], [2], [3], [0], [3], [6], [5], [0], [2], [4], [0], [2]]'

# %% [markdown]
# #4 Model training

# %%
from keras.models import Sequential
from keras import layers
from keras import optimizers
from keras import callbacks 

from tensorflow.keras.layers import LSTM as KERAS_LSTM
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np

from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv1D, \
    Activation, BatchNormalization, MaxPooling1D

# %%
# Initializing the model
model = Sequential()
model.add(Conv2D(
              filters = 1,
              kernel_size = 2,
              padding = 'same',
              input_shape = X.shape[1:4]))  # conv layer

model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Flatten())

model.add(Dense(64)) # fully connvected layer
model.add(BatchNormalization(axis = -1))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(7, activation='softmax')) # fully connvected layer
print(model.summary())

batch_size = 23

# Callbacks functions
checkpoint_path = '/content/drive/My Drive/Colab Notebooks/best_weights.hdf5'

# Save the best weights
mcp_save = callbacks.ModelCheckpoint(checkpoint_path, save_best_only=True,
                           monitor='val_categorical_accuracy',
                           mode='max')                 
# Compile & train   
model.compile(loss='categorical_crossentropy', 
                optimizer='RMSProp', 
                metrics=['categorical_accuracy'])

history = model.fit(x_train, y_train_class, 
                      epochs=50, batch_size = batch_size, 
                      validation_data = (x_val, y_val_class), 
                      callbacks = [mcp_save])
# Define the best weights to the model.
model.load_weights(checkpoint_path)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 3, 288, 1)         1729
#
#  batch_normalization (BatchN  (None, 3, 288, 1)        4
#  ormalization)
#
#  activation (Activation)     (None, 3, 288, 1)         0
#
#  dropout (Dropout)           (None, 3, 288, 1)         0
#
#  flatten (Flatten)           (None, 864)               0
#
#  dense (Dense)               (None, 64)                55360
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 57,804
# Trainable params: 57,674
# Non-trainable params: 130
# _________________________________________________________________
# None
# Epoch 1/50
# 49/49 [==============================] - 13s 229ms/step - loss: 1.3484 - categorical_accuracy: 0.5437 - val_loss: 7.1799 - val_categorical_accuracy: 0.4226
# Epoch 2/50
# 49/49 [==============================] - 7s 150ms/step - loss: 0.5235 - categorical_accuracy: 0.8625 - val_loss: 1.0334 - val_categorical_accuracy: 0.7202
# Epoch 3/50
# 49/49 [==============================] - 7s 151ms/step - loss: 0.3296 - categorical_accuracy: 0.9241 - val_loss: 0.9373 - val_categorical_accuracy: 0.7381
# Epoch 4/50
# 49/49 [==============================] - 8s 161ms/step - loss: 0.2044 - categorical_accuracy: 0.9643 - val_loss: 0.1501 - val_categorical_accuracy: 0.9405
# Epoch 5/50
# 49/49 [==============================] - 8s 157ms/step - loss: 0.1617 - categorical_accuracy: 0.9688 - val_loss: 0.0427 - val_categorical_accuracy: 0.9881
# Epoch 6/50
# 49/49 [==============================] - 7s 153ms/step - loss: 0.1367 - categorical_accuracy: 0.9696 - val_loss: 0.0173 - val_categorical_accuracy: 1.0000
# Epoch 7/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.1129 - categorical_accuracy: 0.9768 - val_loss: 0.0088 - val_categorical_accuracy: 1.0000
# Epoch 8/50
# 49/49 [==============================] - 10s 205ms/step - loss: 0.0852 - categorical_accuracy: 0.9866 - val_loss: 0.0611 - val_categorical_accuracy: 0.9821
# Epoch 9/50
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0897 - categorical_accuracy: 0.9750 - val_loss: 0.0047 - val_categorical_accuracy: 1.0000
# Epoch 10/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0854 - categorical_accuracy: 0.9759 - val_loss: 0.0043 - val_categorical_accuracy: 1.0000
# Epoch 11/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0573 - categorical_accuracy: 0.9848 - val_loss: 0.0037 - val_categorical_accuracy: 1.0000
# Epoch 12/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0577 - categorical_accuracy: 0.9857 - val_loss: 0.0033 - val_categorical_accuracy: 1.0000
# Epoch 13/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0563 - categorical_accuracy: 0.9884 - val_loss: 0.0016 - val_categorical_accuracy: 1.0000
# Epoch 14/50
# 49/49 [==============================] - 7s 141ms/step - loss: 0.0396 - categorical_accuracy: 0.9902 - val_loss: 0.0214 - val_categorical_accuracy: 0.9881
# Epoch 15/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0438 - categorical_accuracy: 0.9884 - val_loss: 0.0106 - val_categorical_accuracy: 1.0000
# Epoch 16/50
# 49/49 [==============================] - 7s 141ms/step - loss: 0.0408 - categorical_accuracy: 0.9911 - val_loss: 0.0032 - val_categorical_accuracy: 1.0000
# Epoch 17/50
# 49/49 [==============================] - 7s 149ms/step - loss: 0.0391 - categorical_accuracy: 0.9893 - val_loss: 0.0053 - val_categorical_accuracy: 1.0000
# Epoch 18/50
# 49/49 [==============================] - 7s 147ms/step - loss: 0.0312 - categorical_accuracy: 0.9929 - val_loss: 0.0018 - val_categorical_accuracy: 1.0000
# Epoch 19/50
# 49/49 [==============================] - 7s 148ms/step - loss: 0.0343 - categorical_accuracy: 0.9902 - val_loss: 0.0067 - val_categorical_accuracy: 1.0000
# Epoch 20/50
# 49/49 [==============================] - 7s 145ms/step - loss: 0.0495 - categorical_accuracy: 0.9875 - val_loss: 0.0038 - val_categorical_accuracy: 1.0000
# Epoch 21/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0303 - categorical_accuracy: 0.9920 - val_loss: 0.0123 - val_categorical_accuracy: 0.9940
# Epoch 22/50
# 49/49 [==============================] - 7s 149ms/step - loss: 0.0251 - categorical_accuracy: 0.9911 - val_loss: 0.0028 - val_categorical_accuracy: 1.0000
# Epoch 23/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0263 - categorical_accuracy: 0.9929 - val_loss: 0.0013 - val_categorical_accuracy: 1.0000
# Epoch 24/50
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0302 - categorical_accuracy: 0.9893 - val_loss: 0.0277 - val_categorical_accuracy: 0.9940
# Epoch 25/50
# 49/49 [==============================] - 7s 144ms/step - loss: 0.0326 - categorical_accuracy: 0.9866 - val_loss: 0.0025 - val_categorical_accuracy: 1.0000
# Epoch 26/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0218 - categorical_accuracy: 0.9964 - val_loss: 3.1392e-04 - val_categorical_accuracy: 1.0000
# Epoch 27/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0200 - categorical_accuracy: 0.9929 - val_loss: 0.0026 - val_categorical_accuracy: 1.0000
# Epoch 28/50
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0188 - categorical_accuracy: 0.9955 - val_loss: 2.5627e-04 - val_categorical_accuracy: 1.0000
# Epoch 29/50
# 49/49 [==============================] - 7s 148ms/step - loss: 0.0227 - categorical_accuracy: 0.9929 - val_loss: 6.5559e-04 - val_categorical_accuracy: 1.0000
# Epoch 30/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0236 - categorical_accuracy: 0.9929 - val_loss: 0.0015 - val_categorical_accuracy: 1.0000
# Epoch 31/50
# 49/49 [==============================] - 7s 144ms/step - loss: 0.0266 - categorical_accuracy: 0.9911 - val_loss: 0.0011 - val_categorical_accuracy: 1.0000
# Epoch 32/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0177 - categorical_accuracy: 0.9946 - val_loss: 0.0016 - val_categorical_accuracy: 1.0000
# Epoch 33/50
# 49/49 [==============================] - 7s 145ms/step - loss: 0.0178 - categorical_accuracy: 0.9964 - val_loss: 2.1194e-04 - val_categorical_accuracy: 1.0000
# Epoch 34/50
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0173 - categorical_accuracy: 0.9955 - val_loss: 3.6500e-04 - val_categorical_accuracy: 1.0000
# Epoch 35/50
# 49/49 [==============================] - 7s 144ms/step - loss: 0.0194 - categorical_accuracy: 0.9973 - val_loss: 4.4061e-04 - val_categorical_accuracy: 1.0000
# Epoch 36/50
# 49/49 [==============================] - 7s 148ms/step - loss: 0.0187 - categorical_accuracy: 0.9929 - val_loss: 3.3664e-04 - val_categorical_accuracy: 1.0000
# Epoch 37/50
# 49/49 [==============================] - 7s 147ms/step - loss: 0.0209 - categorical_accuracy: 0.9937 - val_loss: 4.0482e-04 - val_categorical_accuracy: 1.0000
# Epoch 38/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0262 - categorical_accuracy: 0.9937 - val_loss: 3.2861e-04 - val_categorical_accuracy: 1.0000
# Epoch 39/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0154 - categorical_accuracy: 0.9946 - val_loss: 5.0899e-04 - val_categorical_accuracy: 1.0000
# Epoch 40/50
# 49/49 [==============================] - 7s 149ms/step - loss: 0.0270 - categorical_accuracy: 0.9875 - val_loss: 0.0014 - val_categorical_accuracy: 1.0000
# Epoch 41/50
# 49/49 [==============================] - 7s 144ms/step - loss: 0.0201 - categorical_accuracy: 0.9920 - val_loss: 0.0013 - val_categorical_accuracy: 1.0000
# Epoch 42/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0066 - categorical_accuracy: 0.9991 - val_loss: 3.8763e-04 - val_categorical_accuracy: 1.0000
# Epoch 43/50
# 49/49 [==============================] - 7s 147ms/step - loss: 0.0190 - categorical_accuracy: 0.9946 - val_loss: 1.2158e-04 - val_categorical_accuracy: 1.0000
# Epoch 44/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0089 - categorical_accuracy: 0.9964 - val_loss: 7.5472e-04 - val_categorical_accuracy: 1.0000
# Epoch 45/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0186 - categorical_accuracy: 0.9929 - val_loss: 0.0011 - val_categorical_accuracy: 1.0000
# Epoch 46/50
# 49/49 [==============================] - 7s 148ms/step - loss: 0.0204 - categorical_accuracy: 0.9929 - val_loss: 0.0013 - val_categorical_accuracy: 1.0000
# Epoch 47/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0220 - categorical_accuracy: 0.9920 - val_loss: 0.0030 - val_categorical_accuracy: 1.0000
# Epoch 48/50
# 49/49 [==============================] - 7s 141ms/step - loss: 0.0126 - categorical_accuracy: 0.9991 - val_loss: 0.0020 - val_categorical_accuracy: 1.0000
# Epoch 49/50
# 49/49 [==============================] - 7s 145ms/step - loss: 0.0086 - categorical_accuracy: 0.9973 - val_loss: 2.9221e-04 - val_categorical_accuracy: 1.0000
# Epoch 50/50
# 49/49 [==============================] - 7s 145ms/step - loss: 0.0092 - categorical_accuracy: 0.9964 - val_loss: 2.5193e-04 - val_categorical_accuracy: 1.0000

# %% [markdown]
# #5. MODEL EVALUATION

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 5.1 Accuracy and loss over epoches for train and val dataset

# %%
# Loss, Accuracy presentation

# Plot history: Loss
plt.plot(history.history['loss'], label='Loss (training data)')
plt.plot(history.history['val_loss'], label='Loss (validation data)')
plt.title('Loss for train and validation')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

#Plot history: Accuracy
plt.plot(history.history['categorical_accuracy'], label='Acc (training data)')
plt.plot(history.history['val_categorical_accuracy'], label='Acc (validation data)')
plt.title('Model accuracy')
plt.ylabel('Acc %')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## 5.2 Save & Load model, weights

# %%
# Saving model & weights

from keras.models import model_from_json
from keras.models import load_model

model_json = model.to_json()
saved_model_path = '/content/drive/MyDrive/deep_learning/Speech_Emotion_Recognition/Model_weights/cnn_model.json'
saved_weights_path = '/content/drive/MyDrive/deep_learning/Speech_Emotion_Recognition/Model_weights/cnn_weights.h5'


with open(saved_model_path, "w") as json_file:
    json_file.write(model_json)
    
model.save_weights(saved_weights_path)
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# #6.  Test dataset evaluation

# %%
# !pip install json-tricks

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd
from json_tricks import load

import numpy as np
import os

# %% [markdown]
# ## 6.1 Load the model and test data.

# %%
# Reading the model from JSON file

saved_model_path = '/content/drive/MyDrive/deep_learning/Speech_Emotion_Recognition/Model_weights/cnn_model.json'
saved_weights_path = '/content/drive/MyDrive/deep_learning/Speech_Emotion_Recognition/Model_weights/cnn_weights.h5'

with open(saved_model_path , 'r') as json_file:
    json_savedModel = json_file.read()

# Loading the model architecture, weights
model = tf.keras.models.model_from_json(json_savedModel)
model.load_weights(saved_weights_path)

# Compiling the model with similar parameters as the original model.
model.compile(loss='categorical_crossentropy', 
                optimizer='RMSProp', 
                metrics=['categorical_accuracy'])

# Model's structure visualization
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
# Loading x_test, y_test json files, and converting to np.arrays

x_test = load( 'drive/MyDrive/deep_learning/Speech_Emotion_Recognition/data_set/cnn_x_test.json')
x_test = np.asarray(x_test).astype('float32')

y_test = load('drive/MyDrive/deep_learning/Speech_Emotion_Recognition/data_set/cnn_y_test.json')
y_test = np.asarray(y_test).astype('int8')
print(y_test.shape)
# Out:
# (112, 1)

# %% [markdown]
# ## 6.2 Test Set Evaluation

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# **Test Set Score**

# %%
y_test_class = tf.keras.utils.to_categorical(y_test, 7, dtype = 'int8')
loss, acc = model.evaluate(x_test, y_test_class, verbose=2)
# Out:
# 4/4 - 0s - loss: 9.6426e-04 - categorical_accuracy: 1.0000 - 172ms/epoch - 43ms/step

# %% [markdown]
# **Test Set Confussion Matrix**

# %%
# Test set Confusion matrix
y_test_class = tf.keras.utils.to_categorical(y_test, 7, dtype = 'int8')
y_test_class = np.argmax(y_test_class, axis=1)
predictions = model.predict(x_test)
y_pred_class = np.argmax(predictions, axis=1)

cm=confusion_matrix(y_test_class, y_pred_class)
 
index = ['neutral', 'happy', 'sad', 'angry', 'fear', 'disgust', 'pleasant_surprised'] 

cm_df = pd.DataFrame(cm,index, index)                      
plt.figure(figsize=(12,8))
ax = plt.axes()

sns.heatmap(cm_df, ax = ax, cmap = 'BuGn', fmt="d", annot=True)
ax.set_ylabel('True emotion')
ax.set_xlabel('Predicted emotion')
# Out:
# Text(0.5, 50.09375, 'Predicted emotion')

# %% [markdown]
# **Test Set Predicted emotions accuracy**

# %%
# Test set prediction accuracy rates

values = cm.diagonal()
row_sum = np.sum(cm,axis=1)
acc = values / row_sum

print('Test set predicted emotions accuracy:')
for e in range(0, len(values)):
    print(index[e],':', f"{(acc[e]):0.4f}")
# Out:
# Test set predicted emotions accuracy:
# neutral : 1.0000
# happy : 1.0000
# sad : 1.0000
# angry : 1.0000
# fear : 1.0000
# disgust : 1.0000
# pleasant_surprised : 1.0000
